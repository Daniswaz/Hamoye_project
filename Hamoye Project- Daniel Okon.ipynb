# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
os.chdir('C:\\Users\\Okon Saviour Andem\\Desktop')
os.getcwd()
# %matplotlib inline

# %%
fuel_data=pd.read_csv('fuel_ferc1.csv')
fuel_data
# Out:
#        Unnamed: 0                 record_id  utility_id_ferc1  report_year  \
# 0               0     f1_fuel_1994_12_1_0_7                 1         1994
# 1               1    f1_fuel_1994_12_1_0_10                 1         1994
# 2               2     f1_fuel_1994_12_2_0_1                 2         1994
# 3               3     f1_fuel_1994_12_2_0_7                 2         1994
# 4               4    f1_fuel_1994_12_2_0_10                 2         1994
# 5               5    f1_fuel_1994_12_2_0_13                 2         1994
# 6               6     f1_fuel_1994_12_2_1_1                 2         1994
# 7               7    f1_fuel_1994_12_2_1_10                 2         1994
# 8               8    f1_fuel_1994_12_2_2_10                 2         1994
# 9               9     f1_fuel_1994_12_4_0_1                 4         1994
# 10             10     f1_fuel_1994_12_4_0_2                 4         1994
# ...

# %%
h = fuel_data.groupby('fuel_type_code_pudl').mean()
h
# Out:
#                        Unnamed: 0  utility_id_ferc1  report_year  \
# fuel_type_code_pudl
# coal                 13314.909442        115.637534  2004.623143
# gas                  14993.518631        124.122062  2005.978060
# nuclear              11295.856968        107.397311  2002.970660
# oil                  16428.580481        113.236235  2007.195933
# other                 9700.185629        110.467066  2001.700599
# waste                14582.544218        154.253968  2005.650794
#
#                      fuel_qty_burned  fuel_mmbtu_per_unit  \
# fuel_type_code_pudl
# coal                    1.903473e+06            20.762780
# gas                     4.843183e+06             1.021913
# nuclear                 5.454838e+06            17.582120
# oil                     6.311677e+04             5.814377
# other                   2.948137e+06             0.572752
# waste                   1.171914e+05             0.341163
#
# ...

# %%
h.min()
# Out:
# Unnamed: 0                       9700.185629
# utility_id_ferc1                  107.397311
# report_year                      2001.700599
# fuel_qty_burned                 63116.774802
# fuel_mmbtu_per_unit                 0.341163
# fuel_cost_per_unit_burned          13.659397
# fuel_cost_per_unit_delivered       12.095172
# fuel_cost_per_mmbtu                 1.716559
# dtype: float64

# %%
fuel_data.describe()
# Out:
#          Unnamed: 0  utility_id_ferc1   report_year  fuel_qty_burned  \
# count  29523.000000      29523.000000  29523.000000     2.952300e+04
# mean   14761.000000        118.601836   2005.806050     2.622119e+06
# std     8522.700335         74.178353      7.025483     9.118004e+06
# min        0.000000          1.000000   1994.000000     1.000000e+00
# 25%     7380.500000         55.000000   2000.000000     1.381700e+04
# 50%    14761.000000        122.000000   2006.000000     2.533220e+05
# 75%    22141.500000        176.000000   2012.000000     1.424034e+06
# max    29522.000000        514.000000   2018.000000     5.558942e+08
#
#        fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# count         29523.000000               29523.000000
# mean              8.492111                 208.649031
# std              10.600220                2854.490090
# min               0.000001                -276.080000
# 25%               1.024000                   5.207000
# ...

# %%
fuel_data['fuel_qty_burned'].skew()
# Out:
# 15.851495469109503

# %%
fuel_data['fuel_qty_burned'].kurt()
# Out:
# 651.3694501337732

# %%
fuel_data.isnull().sum()
# Out:
# Unnamed: 0                        0
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
fuel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29523 entries, 0 to 29522
# Data columns (total 12 columns):
# Unnamed: 0                      29523 non-null int64
# record_id                       29523 non-null object
# utility_id_ferc1                29523 non-null int64
# report_year                     29523 non-null int64
# plant_name_ferc1                29523 non-null object
# fuel_type_code_pudl             29523 non-null object
# fuel_unit                       29343 non-null object
# fuel_qty_burned                 29523 non-null float64
# fuel_mmbtu_per_unit             29523 non-null float64
# fuel_cost_per_unit_burned       29523 non-null float64
# fuel_cost_per_unit_delivered    29523 non-null float64
# fuel_cost_per_mmbtu             29523 non-null float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 2.7+ MB

# %%
fuel_data[['fuel_cost_per_unit_burned', 'utility_id_ferc1']].corr()
# Out:
#                            fuel_cost_per_unit_burned  utility_id_ferc1
# fuel_cost_per_unit_burned                   1.000000         -0.037863
# utility_id_ferc1                           -0.037863          1.000000

# %%
fuel_data[['fuel_cost_per_unit_burned', 'fuel_qty_burned']].corr()
# Out:
#                            fuel_cost_per_unit_burned  fuel_qty_burned
# fuel_cost_per_unit_burned                   1.000000        -0.018535
# fuel_qty_burned                            -0.018535         1.000000

# %%
fuel_data[['fuel_cost_per_unit_burned', 'report_year']].corr()
# Out:
#                            fuel_cost_per_unit_burned  report_year
# fuel_cost_per_unit_burned                   1.000000     0.013599
# report_year                                 0.013599     1.000000

# %%
fuel_data.groupby('fuel_type_code_pudl').first()
# Out:
#                      Unnamed: 0               record_id  utility_id_ferc1  \
# fuel_type_code_pudl
# coal                          0   f1_fuel_1994_12_1_0_7                 1
# gas                           4  f1_fuel_1994_12_2_0_10                 2
# nuclear                       6   f1_fuel_1994_12_2_1_1                 2
# oil                          14   f1_fuel_1994_12_6_0_2                 6
# other                        84  f1_fuel_1994_12_11_0_6                11
# waste                        49   f1_fuel_1994_12_9_0_3                 9
#
#                      report_year  plant_name_ferc1 fuel_unit  fuel_qty_burned  \
# fuel_type_code_pudl
# coal                        1994          rockport       ton        5377489.0
# gas                         1994         chickasaw       mcf          40533.0
# nuclear                     1994  joseph m. farley       kgU           2260.0
# oil                         1994      clinch river       bbl           6510.0
# ...

# %%
g = fuel_data.groupby('report_year').mean()
g
# Out:
#              Unnamed: 0  utility_id_ferc1  fuel_qty_burned  \
# report_year
# 1994              617.0        106.120648     2.724018e+06
# 1995             1835.0        110.139051     3.712067e+06
# 1996             2979.5        108.714154     2.544754e+06
# 1997             4070.5        108.366545     2.813503e+06
# 1998             5171.0        109.845528     3.267453e+06
# 1999             6249.5        108.222857     3.281281e+06
# 2000             7461.0        111.083758     2.472032e+06
# 2001             8825.5        113.521386     2.321402e+06
# 2002            10106.0        120.354357     2.145645e+06
# 2003            11314.0        123.300578     1.888622e+06
# 2004            12515.5        121.123322     1.782547e+06
# 2005            13746.0        121.028369     1.768876e+06
# 2006            15002.0        117.178600     1.957264e+06
# 2007            16255.5        116.040348     2.035696e+06
# 2008            17501.5        120.785016     2.046455e+06
# ...

# %%
g.max()
# Out:
# Unnamed: 0                      2.904700e+04
# utility_id_ferc1                1.336698e+02
# fuel_qty_burned                 4.178890e+06
# fuel_mmbtu_per_unit             1.077804e+01
# fuel_cost_per_unit_burned       4.423591e+02
# fuel_cost_per_unit_delivered    1.114020e+04
# fuel_cost_per_mmbtu             3.687364e+02
# dtype: float64
